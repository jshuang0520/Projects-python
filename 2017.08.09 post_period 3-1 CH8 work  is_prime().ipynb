# %%
#debug後的版本 : 
#自訂函數 1.1：寫一個判斷輸入的正整數是否為質數的函數 is_prime()

def is_prime(x) :
    '''
    這是一個自訂函數，用來判斷輸入的正整數是否為質數
    '''
    try :
        if x <= 0 :
            return "您輸入的是 %s 。不好意思，請輸入正整數!" % x
        elif x == 1 :
            return "1 既不是質數，也不是合數喔!" 
        elif x == 2 :
            return "2 是質數"
        else :
            for a in range(2, x) :
                while x % a == 0 :
                    return "%i 不是質數而是合數喔!" % x 
                    break
        return "%i 是質數" % x
    except :
            return "您輸入的是 %s 。輸入的值不是屬於實數就好。還必須是正整數!" % x 


        
        
        
print(is_prime(2))
print(is_prime(3))  
print(is_prime(5))
print(is_prime(7))
print(is_prime(11))
print(is_prime(13))
print(is_prime(17))
print(is_prime(19))
print(is_prime(83))
print(is_prime(89))
print(is_prime(97))
print(is_prime(101))
print(is_prime(-1))
print(is_prime(-1.2)) 
print(is_prime(0))
print(is_prime(0.2))    
print(is_prime(1))    
print(is_prime(2.2)) 
print(is_prime(7.2)) 
print(is_prime(4))
print(is_prime(6))
print(is_prime(8))
print(is_prime(9))      
print(is_prime(10))
print(is_prime(15))     
print(is_prime(21))    
print(is_prime(1000000000000))
print(is_prime(1000000000011))
# Out:
# 2 是質數
# 3 是質數
# 5 是質數
# 7 是質數
# 11 是質數
# 13 是質數
# 17 是質數
# 19 是質數
# 83 是質數
# 89 是質數
# 97 是質數
# 101 是質數
# 您輸入的是 -1 。不好意思，請輸入正整數!
# 您輸入的是 -1.2 。不好意思，請輸入正整數!
# 您輸入的是 0 。不好意思，請輸入正整數!
# 您輸入的是 0.2 。輸入的值不是屬於實數就好。還必須是正整數!
# 1 既不是質數，也不是合數喔!
# 您輸入的是 2.2 。輸入的值不是屬於實數就好。還必須是正整數!
# 您輸入的是 7.2 。輸入的值不是屬於實數就好。還必須是正整數!
# 4 不是質數而是合數喔!
# 6 不是質數而是合數喔!
# 8 不是質數而是合數喔!
# 9 不是質數而是合數喔!
# 10 不是質數而是合數喔!
# 15 不是質數而是合數喔!
# 21 不是質數而是合數喔!
# 1000000000000 不是質數而是合數喔!
# 1000000000011 不是質數而是合數喔!

# %%
#修正過後的版本2，仍有bug
#自訂函數 1.1：寫一個判斷輸入的正整數是否為質數的函數 is_prime()
def is_prime(x) :
    '''
    這是一個自訂函數，用來判斷輸入的正整數是否為質數
    '''
    try :
        if x <= 0 :
            return "您輸入的是%s。不好意思，請輸入正整數!" % x
        elif x == 1 :
            return "1既不是質數，也不是合數!" 
        elif x == 2 :
            return "2是質數"
        elif x > 2 :
            for a in range(2, x) :
                if x % a == 0 :                                  #現在差這行而已
                        return "%i不是質數喔!" % x 
                else :                                      #因為判定正確，但質數印不出來
                    return "%i是質數" % x     
        else :
            return "您所輸入的是%f。不好意思，請輸入正整數!" % x
    except :
            return "輸入的值不是屬於實數就好。必須屬於正整數!" 
print(is_prime(-1))
print(is_prime(-1.2)) 
print(is_prime(0))
print(is_prime(0.2))    
print(is_prime(1))    
print(is_prime(2))

print(is_prime(2.2))    #(OK已修正)<---------- Q1 期望出現"您所輸入的是2.2。不好意思，請輸入正整數!"，但卻出現"發生錯誤，請輸入正整數!" 

print(is_prime(3))      #<---------- Q3 這次換質數印不出來
print(is_prime(4))
print(is_prime(5))
print(is_prime(6))
print(is_prime(7))
print(is_prime(8))

print(is_prime(9))      #(OK已修正)<---------- Q2   奇數都被錯判

print(is_prime(10))
print(is_prime(15))     #(OK已修正)<---------- Q2
print(is_prime(21))     #(OK已修正)<---------- Q2

print(is_prime(83))
print(is_prime(89))
print(is_prime(97))
print(is_prime(101))
print(is_prime(1000000000000))
print(is_prime(1000000000011))    #(OK已修正)<---------- Q2
# Out:
# 您輸入的是-1。不好意思，請輸入正整數!
# 您輸入的是-1.2。不好意思，請輸入正整數!
# 您輸入的是0。不好意思，請輸入正整數!
# 您所輸入的是0.200000。不好意思，請輸入正整數!
# 1既不是質數，也不是合數!
# 2是質數
# 輸入的值不是屬於實數就好。必須屬於正整數!
# 3是質數
# 4不是質數喔!
# 5是質數
# 6不是質數喔!
# 7是質數
# 8不是質數喔!
# 9是質數
# 10不是質數喔!
# 15是質數
# 21是質數
# 83是質數
# 89是質數
# 97是質數
# 101是質數
# 1000000000000不是質數喔!
# 1000000000011是質數

# %%
#修正過後的版本1，仍有bug
#自訂函數 1.1：寫一個判斷輸入的正整數是否為質數的函數 is_prime()
def is_prime(x) :
    '''
    這是一個自訂函數，用來判斷輸入的正整數是否為質數
    '''
    try :
        if x <= 0 :
            return "您輸入的是%s。不好意思，請輸入正整數!" % x
        elif x == 1 :
            return "1既不是質數，也不是合數!" 
        elif x == 2 :
            return "2是質數"
        elif x > 2 :
            for a in range(2, x) :
                while x % a == 0 :
                    return "%i不是質數喔!" % x 
                    break
        else :
            return "%i是質數" % x
    except :
            return "輸入的值不是屬於實數就好。必須屬於正整數!" 
print(is_prime(-1))
print(is_prime(-1.2)) 
print(is_prime(0))
print(is_prime(0.2))    
print(is_prime(1))    
print(is_prime(2))

print(is_prime(2.2))    #(OK已修正)<---------- Q1 期望出現"您所輸入的是2.2。不好意思，請輸入正整數!"，但卻出現"發生錯誤，請輸入正整數!" 

print(is_prime(3))      #<---------- Q3 這次換質數印不出來
print(is_prime(4))
print(is_prime(5))
print(is_prime(6))
print(is_prime(7))
print(is_prime(8))

print(is_prime(9))      #(OK已修正)<---------- Q2   奇數都被錯判

print(is_prime(10))
print(is_prime(15))     #(OK已修正)<---------- Q2
print(is_prime(21))     #(OK已修正)<---------- Q2

print(is_prime(83))
print(is_prime(89))
print(is_prime(97))
print(is_prime(101))
print(is_prime(1000000000000))
print(is_prime(1000000000011))    #(OK已修正)<---------- Q2
# Out:
# 您輸入的是-1。不好意思，請輸入正整數!
# 您輸入的是-1.2。不好意思，請輸入正整數!
# 您輸入的是0。不好意思，請輸入正整數!
# 0是質數
# 1既不是質數，也不是合數!
# 2是質數
# 輸入的值不是屬於實數就好。必須屬於正整數!
# None
# 4不是質數喔!
# None
# 6不是質數喔!
# None
# 8不是質數喔!
# 9不是質數喔!
# 10不是質數喔!
# 15不是質數喔!
# 21不是質數喔!
# None
# None
# None
# None
# 1000000000000不是質數喔!
# 1000000000011不是質數喔!

# %%
#實驗，有bug
x=100
def 因數(x):
    for a in range(2, x) :
        if x % a == 0 :
            return ("%s不是質數喔!") % x
        else:
            return ("%s是質數!") % x
print(因數(15))
# Out:
# 15是質數!

# %%
#實驗
x=100
def 因數(x):
    質數_list=[]
    for a in range(2, x) :
        if x % a == 0 :
            continue
        else:
            質數_list.append(a)
            return 質數_list
            
print(因數(x))
# Out:
# [3]

# %%
def is_prime(x) :
    '''
    這是一個自訂函數，用來判斷輸入的正整數是否為質數
    '''
    try :
        if x <= 0 :
            return "您輸入的是 %s 。不好意思，請輸入正整數!" % x
        elif x == 1 :
            return "1 既不是質數，也不是合數喔!" 
        elif x == 2 :
            return "2 是質數"
        else :
            for a in range(2, x) :
                while x % a == 0 :
                    return "%i 不是質數而是合數喔!" % x 
                    break
        return "%i 是質數" % x
    except :
            return "您輸入的是 %s 。輸入的值不是屬於實數就好。還必須是正整數!" % x 


        
        
        
print(is_prime(2))
print(is_prime(3))  
print(is_prime(5))
print(is_prime(7))
print(is_prime(11))
print(is_prime(13))
print(is_prime(17))
print(is_prime(19))
print(is_prime(83))
print(is_prime(89))
print(is_prime(97))
print(is_prime(101))
print('\n')
print(is_prime(-1))
print(is_prime(-1.2)) 
print(is_prime(0))
print(is_prime(0.2))    
print(is_prime(1))    
print(is_prime(2.2)) 
print(is_prime(7.2)) 
print('\n')     
print(is_prime(4))
print(is_prime(6))
print(is_prime(8))
print(is_prime(9))      
print(is_prime(10))
print(is_prime(15))     
print(is_prime(21))    
print(is_prime(1000000000000))
print(is_prime(1000000000011))
# Out:
# 2 是質數
# 3 是質數
# 5 是質數
# 7 是質數
# 11 是質數
# 13 是質數
# 17 是質數
# 19 是質數
# 83 是質數
# 89 是質數
# 97 是質數
# 101 是質數
#
#
# 您輸入的是 -1 。不好意思，請輸入正整數!
# 您輸入的是 -1.2 。不好意思，請輸入正整數!
# 您輸入的是 0 。不好意思，請輸入正整數!
# 您輸入的是 0.2 。輸入的值不是屬於實數就好。還必須是正整數!
# 1 既不是質數，也不是合數喔!
# 您輸入的是 2.2 。輸入的值不是屬於實數就好。還必須是正整數!
# 您輸入的是 7.2 。輸入的值不是屬於實數就好。還必須是正整數!
#
#
# 4 不是質數而是合數喔!
# 6 不是質數而是合數喔!
# 8 不是質數而是合數喔!
# 9 不是質數而是合數喔!
# 10 不是質數而是合數喔!
# 15 不是質數而是合數喔!
# 21 不是質數而是合數喔!
# 1000000000000 不是質數而是合數喔!
# 1000000000011 不是質數而是合數喔!

# %%
#為了1.2題 改成True / False

def is_prime(x) :
    '''
    這是一個自訂函數，用來判斷輸入的正整數是否為質數
    '''
    try :
        if x <= 0 :
            return False
        elif x == 1 :
            return False
        elif x == 2 :
            return True
        else :
            for a in range(2, x) :
                while x % a == 0 :
                    return False
                    break
        return True
    except :
            return False 


        
        
        
print(is_prime(2))
print(is_prime(3))  
print(is_prime(5))
print(is_prime(7))
print(is_prime(11))
print(is_prime(13))
print(is_prime(17))
print(is_prime(19))
print(is_prime(83))
print(is_prime(89))
print(is_prime(97))
print(is_prime(101))
print('\n')
print(is_prime(-1))
print(is_prime(-1.2)) 
print(is_prime(0))
print(is_prime(0.2))    
print(is_prime(1))    
print(is_prime(2.2))   
print(is_prime(7.2))   
print('\n')     
print(is_prime(4))
print(is_prime(6))
print(is_prime(8))
print(is_prime(9))      
print(is_prime(10))
print(is_prime(15))     
print(is_prime(21))    
print(is_prime(1000000000000))
print(is_prime(1000000000011))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
#
#
# False
# False
# False
# False
# False
# False
# False
#
#
# False
# False
# False
# False
# False
# False
# False
# False
# False
